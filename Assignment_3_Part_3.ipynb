# %% [markdown]
# ## Exercise

# %% [markdown]
# For this exercise, you will be working with the [House Price Dataset](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/code).
#
# Please grab the train.csv file from Kaggle and explore this dataset. You need to perform explroatory data analysis and see if there is any correlation between the variables and analyze the distribution of the dataset. The question is open-ended and basically you're asked to perform EDA.

# %% [markdown]
# 1- Write a summary of your findings in one page (e.g., summary statistics, plots) and submit the pdf file. Therefore, for part 3 of your assignment, you need to submit at least one jupyter notebook file and one pdf file.
#
#
# 2- Push your code and project to github and provide the link to your code here. Ensure that your github project is organized to at least couple of main folders, ensure that you have the README file as well:
#
# - Src
# - Data
# - Docs
# - Results
#
# Read this link for further info:  https://gist.github.com/ericmjl/27e50331f24db3e8f957d1fe7bbbe510

# %% [markdown]
# ### Some pre-works to do with the dataset such as importing necessary libraries, exploring the dataset, going through all the variables types, and checking out if there is missing data

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
hdf=pd.read_csv('train.csv')

# %%
hdf.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
hdf.columns

# %%
hdf.info
# Out:
# <bound method DataFrame.info of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
hdf.describe
# Out:
# <bound method NDFrame.describe of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
hdf.isnull()
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     False       False     False        False    False   False   True
# 1     False       False     False        False    False   False   True
# 2     False       False     False        False    False   False   True
# 3     False       False     False        False    False   False   True
# 4     False       False     False        False    False   False   True
# ...     ...         ...       ...          ...      ...     ...    ...
# 1455  False       False     False        False    False   False   True
# 1456  False       False     False        False    False   False   True
# 1457  False       False     False        False    False   False   True
# 1458  False       False     False        False    False   False   True
# 1459  False       False     False        False    False   False   True
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %% [markdown]
# ### There are columns that are full of NA values and they are 'Alley' , 'PoolQC', 'Fence', and 'MiscFeature.
# ### That makes sense in this dataset because not every house has fence or pool when being designed and built.
# ### Since the following operations will focus on those numerical variables to compute their correlation coefficients, and only the strong related pairs will be picked to study, columns with NA values will not affect the following result. Therefore they can be kept in the dataset.

# %% [markdown]
# ### Now that the dataset is huge with total of 81 columns, it will be ineffient if looking at all the variables and pair them all up. Therefore, I plan to focus on those whose have the higher correlation ( cor>= 0.5, or cor<= -0.5) and neglecting those whose correlation is relatively closer to Zero ( -0.5 < cor < 0.5 ) .

# %% [markdown]
# ### 1. First thing to do is generating all correlation for all the pairs

# %%
corr_table=hdf.corr()

# %%
type(corr_table)

# %%
corr_table
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %% [markdown]
# ### 2. Define a function that takes the whole cor-table as arguement and return a list of tuples with three elements in side each tuple. They are 1. exact correlation that is higher equal to 0.5, or lower equal to -0.5; and 2. the two names of the  pairs.

# %%
def higherCor(correlation_table):
    var_list=list(correlation_table.columns)
    list_cor=[]
    for var1 in var_list:
        for var2 in var_list:
            cor_value=corr_table.loc[var1,var2]
            if cor_value>=0.5 or cor_value<=-0.5:
                list_cor.append((var1,var2,cor_value))
    return list_cor

# %%
original_list=higherCor(corr_table)

# %%
original_list### Note that this list contains all pairs within the cor-table including those that pairs up with it self E.g. ('Id','Id','1.0'), which are meaningless for the study.
# Out:
# [('Id', 'Id', 1.0),
#  ('MSSubClass', 'MSSubClass', 1.0),
#  ('LotFrontage', 'LotFrontage', 1.0),
#  ('LotArea', 'LotArea', 1.0),
#  ('OverallQual', 'OverallQual', 1.0),
#  ('OverallQual', 'YearBuilt', 0.572322768962362),
#  ('OverallQual', 'YearRemodAdd', 0.550683924194174),
#  ('OverallQual', 'TotalBsmtSF', 0.5378084986123927),
#  ('OverallQual', 'GrLivArea', 0.5930074300286511),
#  ('OverallQual', 'FullBath', 0.5505997093682552),
#  ('OverallQual', 'GarageYrBlt', 0.5477658448351637),
#  ('OverallQual', 'GarageCars', 0.6006707165907189),
#  ('OverallQual', 'GarageArea', 0.5620217566126064),
#  ('OverallQual', 'SalePrice', 0.7909816005838047),
#  ('OverallCond', 'OverallCond', 1.0),
#  ('YearBuilt', 'OverallQual', 0.572322768962362),
#  ('YearBuilt', 'YearBuilt', 1.0),
#  ('YearBuilt', 'YearRemodAdd', 0.5928549763436497),
#  ('YearBuilt', 'GarageYrBlt', 0.8256674841743434),
#  ('YearBuilt', 'GarageCars', 0.5378500917111045),
#  ('YearBuilt', 'SalePrice', 0.5228973328794967),
# ...

# %% [markdown]
# ### 3.Creating a new list with all unique pairs and corelation that is not equal to 1 based on the original list generated from the last step

# %%
def newlistcor(somelist):
    '''Creating a new list called new_list1 to contain those pairs that are not itself and have the correlation of 1''' 
    new_list1=[]
    '''Using for loop to iterate each tuple within the original list and only select those that is not pairing itself'''
    for pair in somelist:
        if pair[2]!=1.0:
            new_list1.append(pair)
    '''After having a list contained with pairs that formed with differet variables, we sort the list in ascending order according to the coefficient so that the duplicate pairs will stick together'''        
    new_list2=sorted(new_list1,key=lambda x: x[2])
    '''Once all the duplicate tuples have stick together, we now can use the sllicing method to only pick up the second item every two item to create a list that only contain the unique pair with its coefficient value'''
    final_list=new_list2[::2]
    return final_list

# %%
strong_cor_list=newlistcor(original_list)
strong_cor_list
# Out:
# [('2ndFlrSF', 'BedroomAbvGr', 0.5029006133459021),
#  ('YearRemodAdd', 'SalePrice', 0.5071009671113867),
#  ('GrLivArea', 'BedroomAbvGr', 0.5212695109189988),
#  ('BsmtFinSF1', 'TotalBsmtSF', 0.5223960519923907),
#  ('YearBuilt', 'SalePrice', 0.5228973328794967),
#  ('TotRmsAbvGrd', 'SalePrice', 0.5337231555820238),
#  ('OverallQual', 'TotalBsmtSF', 0.5378084986123927),
#  ('YearBuilt', 'GarageCars', 0.5378500917111045),
#  ('OverallQual', 'GarageYrBlt', 0.5477658448351637),
#  ('OverallQual', 'FullBath', 0.5505997093682552),
#  ('OverallQual', 'YearRemodAdd', 0.550683924194174),
#  ('FullBath', 'TotRmsAbvGrd', 0.5547842535334817),
#  ('FullBath', 'SalePrice', 0.5606637627484452),
#  ('OverallQual', 'GarageArea', 0.5620217566126064),
#  ('GarageYrBlt', 'GarageArea', 0.5645670607230588),
#  ('1stFlrSF', 'GrLivArea', 0.5660239689357487),
#  ('OverallQual', 'YearBuilt', 0.572322768962362),
#  ('GarageYrBlt', 'GarageCars', 0.5889200070047019),
# ...

# %% [markdown]
# ### Conclusion for up to step 3:
# ### a. There are total of 38 unique pairs of variables that have obvious relationship;
# ### b. The dataset does not have variables that have obvious negative relationship as there are no correlation that is smaller that -0.5;
# ### c. All obvious relationships between variables are positively related because they are all larger or equal to 0.5

# %% [markdown]
# ###
# ###
# ### 4. Since our main focus is on the SalePrice, we will first look into those pairs have the 'SalePrice' as one of the elements

# %%
cor_with_saleprice=[]
for pair in strong_cor_list:
    if 'SalePrice' in pair:
        cor_with_saleprice.append(pair)

# %%
len(cor_with_saleprice)
# Out:
# 10

# %%
cor_with_saleprice
# Out:
# [('YearRemodAdd', 'SalePrice', 0.5071009671113867),
#  ('YearBuilt', 'SalePrice', 0.5228973328794967),
#  ('TotRmsAbvGrd', 'SalePrice', 0.5337231555820238),
#  ('FullBath', 'SalePrice', 0.5606637627484452),
#  ('1stFlrSF', 'SalePrice', 0.6058521846919166),
#  ('TotalBsmtSF', 'SalePrice', 0.6135805515591944),
#  ('GarageArea', 'SalePrice', 0.6234314389183598),
#  ('GarageCars', 'SalePrice', 0.640409197258349),
#  ('GrLivArea', 'SalePrice', 0.7086244776126511),
#  ('OverallQual', 'SalePrice', 0.7909816005838047)]

# %% [markdown]
# ### Conclusion up the step 4:
# ### As the list of correlations has been sorted in ascending order before, for SalePrice, variables from highly related to moderately related are: 'OveralLQual', 'GrLivArea' ,'GarageCars', 'GarageArea', 'TotalBsmtSF', '1stFlorSF', 'FullBath', 'ToRmsAbvGrd', 'YearBuilt', 'YearTemodAdd'.

# %% [markdown]
# ### 5. Plotting out scatter chart for those 10 pairs

# %%
### 'OverallQual' vs 'SalePrice'
sns.lmplot(x = 'OverallQual', y = 'SalePrice', data = hdf, fit_reg = True, palette = "Set1")

# %%
### 'GrLivArea = Above grade living Area' vs 'SalePrice'
sns.lmplot(x = 'GrLivArea', y = 'SalePrice', data = hdf, fit_reg = True, palette = "Set1")

# %%
### 'GarageCars' vs 'SalePrice'
sns.lmplot(x = 'GarageCars', y = 'SalePrice', data = hdf, fit_reg = True, palette = "Set1")

# %%
### 'GarageArea' vs 'SalePrice'
sns.lmplot(x = 'GarageArea', y = 'SalePrice', data = hdf, fit_reg = True, palette = "Set1")

# %%
### 'TotalBsmtSF' vs 'SalePrice'
sns.lmplot(x = 'TotalBsmtSF', y = 'SalePrice', data = hdf, fit_reg = True, palette = "Set1")

# %%
### '1stFlrSF' vs 'SalePrice'
sns.lmplot(x = '1stFlrSF', y = 'SalePrice', data = hdf, fit_reg = True, palette = "Set1")

# %%
### 'FullBath = Full size bathrooms above grade' vs 'SalePrice'
sns.lmplot(x = 'FullBath', y = 'SalePrice', data = hdf, fit_reg = True, palette = "Set1")

# %%
### 'TotRmsAbvGrd = Total rooms above grade (does not include bathrooms)' vs 'SalePrice'
sns.lmplot(x = 'TotRmsAbvGrd', y = 'SalePrice', data = hdf, fit_reg = True, palette = "Set1")

# %%
### 'YearBuilt' vs 'SalePrice'
sns.lmplot(x = 'YearBuilt', y = 'SalePrice', data = hdf, fit_reg = True, palette = "Set1")

# %%
### 'YearRemodAdd = Year of remodeling' vs 'SalePrice'
sns.lmplot(x = 'YearRemodAdd', y = 'SalePrice', data = hdf, fit_reg = True, palette = "Set1")

# %% [markdown]
# ### 6. Extensional study:
# ### As now we have found that it is the 'OverallQual' that has the best positive effect on 'SalePrice', then what variables are most related to 'OverallQual' except 'SalePrice'?

# %%
cor_with_overallqual=[]
for pair in strong_cor_list:
    if 'OverallQual' in pair:
        cor_with_overallqual.append(pair)

# %%
cor_with_overallqual
# Out:
# [('OverallQual', 'TotalBsmtSF', 0.5378084986123927),
#  ('OverallQual', 'GarageYrBlt', 0.5477658448351637),
#  ('OverallQual', 'FullBath', 0.5505997093682552),
#  ('OverallQual', 'YearRemodAdd', 0.550683924194174),
#  ('OverallQual', 'GarageArea', 0.5620217566126064),
#  ('OverallQual', 'YearBuilt', 0.572322768962362),
#  ('OverallQual', 'GrLivArea', 0.5930074300286511),
#  ('OverallQual', 'GarageCars', 0.6006707165907189),
#  ('OverallQual', 'SalePrice', 0.7909816005838047)]

# %% [markdown]
# ### In conclusion: Statistically, 'GarageCars', the number of cars that a garage is capable to contain has the largest positive correlation with the overall quality.
